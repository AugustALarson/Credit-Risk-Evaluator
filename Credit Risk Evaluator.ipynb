# %%
# Imports
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Reading in the CV files
train_df = pd.read_csv(Path('Resources/Generator/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/Generator/2020Q1loans.csv'))

# %%
# Converting categorical data to numeric and separating target feature for training data
X_train = train_df
X_train = pd.get_dummies(X[train_df.drop('target', axis=1)])
# Out:
#        high_risk  low_risk
# 0              0         1
# 1              0         1
# 2              0         1
# 3              0         1
# 4              0         1
# ...          ...       ...
# 12175          1         0
# 12176          1         0
# 12177          1         0
# 12178          1         0
# 12179          1         0
#
# [12180 rows x 2 columns]

# %%
# Converting categorical data to numeric and separating target feature for testing data
X = test_df
pd.get_dummies(X['target'])
# Out:
#       high_risk  low_risk
# 0             0         1
# 1             0         1
# 2             0         1
# 3             0         1
# 4             0         1
# ...         ...       ...
# 4697          1         0
# 4698          1         0
# 4699          1         0
# 4700          1         0
# 4701          1         0
#
# [4702 rows x 2 columns]

# %%
# Adding missing dummy variables to testing set
X_train = train_df.drop('target', axis=1)
X_train = pd.get_dummies(X_train)
X_train = X_train.drop('debt_settlement_flag_Y', axis=1)
y_train = train_df['target']
X_test = test_df.drop('target', axis=1)
X_test = pd.get_dummies(X_test)
y_test = test_df['target']

X_train
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0         7000.0    0.1894       256.38     75000.0  28.62          0.0
# 1        40000.0    0.1614       975.71    102000.0  11.72          2.0
# 2        11000.0    0.2055       294.81     45000.0  37.25          1.0
# 3         4000.0    0.1612       140.87     38000.0  42.89          1.0
# 4        14000.0    0.1797       505.93     43000.0  22.16          1.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# ...

# %%
X_test
# Out:
#       loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0       40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1       24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2       13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3       10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4        6375.0    0.1862       232.46     60000.0  35.50          0.0
# ...         ...       ...          ...         ...    ...          ...
# 4697    30000.0    0.1240       673.42    140480.0  15.74          0.0
# 4698    24000.0    0.0756       747.22     50000.0  26.81          0.0
# 4699    10000.0    0.2305       387.36     33000.0  38.51          0.0
# 4700     8000.0    0.1862       205.86     38000.0  16.36          0.0
# 4701    30000.0    0.2055      1123.34    180000.0  12.06          0.0
#
#       inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                1.0       8.0      0.0    38113.0  ...
# ...

# %%
# Training the Logistic Regression model on the unscaled data

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
# Fitting the model

model.fit(X_train, y_train)
# Out:
# C:\Users\colmu\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
# Scoring the model

model.score(X_test, y_test)
# Out:
# 0.5078689919183327

# %%
# Training a Random Forest Classifier model and printing the model score

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6439812845597618

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
X_test_scaled = scaler.transform(X_test)

# %%
# Training the Logistic Regression model on the scaled data and printing the model score

mod = LogisticRegression()

linreg = mod.fit(X_train_scaled, y_train)
print(f'Training Score: {linreg.score(X_train_scaled, y_train)}')
print(f'Testing Score: {linreg.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 0.7108374384236453
# Testing Score: 0.7596767333049766
# C:\Users\colmu\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
# Training a Random Forest Classifier model on the scaled data and printing the model score

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6439812845597618
